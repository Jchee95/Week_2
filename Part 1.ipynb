# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

df1 = pd.read_csv('C:/Users/user/Downloads/passengerData.csv')
df2 = pd.read_excel('C:/Users/user/Downloads/ticketPrices.xlsx')

df2
# Out:
#    TicketType  Fare
# 0           1    33
# 1           2    56
# 2           3    77
# 3           4    22
# 4           5    14
# 5           6    66
# 6           7    87
# 7           8    36

# %%
df3 = pd.merge(df1, df2, on="TicketType")
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
age = df3["Age"]
oldest = age.max()

# %%
oldest_name = df3["Name"][df3.Age==oldest]

# %%
oldest_name.values
# Out:
# array(['Barkworth, Mr. Algernon Henry Wilson'], dtype=object)

# %%
df3 = pd.merge(df1, df2)
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              9         1       3
# 2             17         0       3
# 3             25         0       3
# 4             33         1       3
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 2                                 Rice, Master. Eugene    male   2.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# ..                                                 ...     ...   ...
# ...

# %%
plt.scatter(df3["Age"], df3["Fare"])

# %%
f_pass = df3[df3.Sex=='female']
f_pass
# Out:
#      PassengerId  Survived  Pclass  \
# 1              9         1       3
# 3             25         0       3
# 4             33         1       3
# 5             41         0       3
# 7             57         1       2
# ..           ...       ...     ...
# 886          856         1       3
# 887          864         0       3
# 888          872         1       1
# 889          880         1       1
# 890          888         1       1
#
#                                                   Name     Sex   Age  \
# 1    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 3                        Palsson, Miss. Torborg Danira  female   8.0
# 4                             Glynn, Miss. Mary Agatha  female   NaN
# 5       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 7                                    Rugg, Miss. Emily  female  21.0
# ..                                                 ...     ...   ...
# ...

# %%
f_age = f_pass[f_pass.Age.between(40,50)]
f_age
# Out:
#      PassengerId  Survived  Pclass  \
# 5             41         0       3
# 34           273         1       2
# 54           433         1       2
# 55           441         1       2
# 92           737         0       3
# 107          857         1       1
# 132          162         1       2
# 134          178         0       1
# 154          338         1       1
# 188          610         1       1
# 220          866         1       2
# 248          195         1       1
# 267          347         1       2
# 269          363         0       3
# 281          459         1       2
# 312          707         1       2
# 318          755         1       2
# 368          260         1       2
# 373          300         1       1
# 401          524         1       1
# 433          780         1       1
# 453           53         1       1
# 463          133         0       3
# 481          277         0       3
# 494          381         1       1
# ...

# %%
max_pay = df3.Fare.max()
f_pay = f_age[f_age.Fare.between(40, max_pay)]
f_pay
# Out:
#      PassengerId  Survived  Pclass  \
# 132          162         1       2
# 134          178         0       1
# 154          338         1       1
# 188          610         1       1
# 220          866         1       2
# 248          195         1       1
# 267          347         1       2
# 269          363         0       3
# 281          459         1       2
# 312          707         1       2
# 318          755         1       2
# 700          255         0       3
# 734          527         1       2
# 748          639         0       3
# 752          671         1       2
# 753          679         0       3
# 775          855         0       2
# 776          863         1       1
#
#                                                   Name     Sex   Age  \
# 132  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0
# 134                         Isham, Miss. Ann Elizabeth  female  50.0
# 154                    Burns, Miss. Elizabeth Margaret  female  41.0
# ...

# %%
plt.scatter(data=f_pay, x='Age', y='Fare')
